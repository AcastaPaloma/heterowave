# %%
from huggingface_hub import list_repo_files

files = list_repo_files(
    repo_id="OpenBreastUS/breast",
    repo_type="dataset",
)

for filename in files:
    print(filename)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# .gitattributes
# OpenWavesInstaller.zip
# README.md
# breast_test_speed.mat
# breast_train_speed.mat
# sample/test_1.mat
# sample/test_2.mat
# sample/test_3.mat
# sample/test_4.mat
# split_data.m

# %%
from pathlib import Path
from huggingface_hub import hf_hub_download

destination = Path(
    "/content/drive/MyDrive/heterowave/raw/openbreastus"
)
destination.mkdir(parents=True, exist_ok=True)

wanted_files = [
    "breast_train_speed.mat",
    "breast_test_speed.mat",
]

for filename in wanted_files:
    path = hf_hub_download(
        repo_id="OpenBreastUS/breast",
        repo_type="dataset",
        filename=filename,
        local_dir=str(destination),
    )
    print("Downloaded:", path)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# breast_train_speed.mat:   0%|          | 0.00/1.69G [00:00<?, ?B/s]
# Downloaded: /content/drive/MyDrive/heterowave/raw/openbreastus/breast_train_speed.mat
# breast_test_speed.mat:   0%|          | 0.00/205M [00:00<?, ?B/s]
# Downloaded: /content/drive/MyDrive/heterowave/raw/openbreastus/breast_test_speed.mat

# %%
from pathlib import Path

root = Path("/content/drive/MyDrive/heterowave/raw/openbreastus")

for path in root.rglob("*.mat"):
    print(path, round(path.stat().st_size / 1024**3, 3), "GB")
# Out:
# /content/drive/MyDrive/heterowave/raw/openbreastus/breast_train_speed.mat 1.573 GB
# /content/drive/MyDrive/heterowave/raw/openbreastus/breast_test_speed.mat 0.191 GB
